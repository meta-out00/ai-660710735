# %% [markdown]
# # 660710735 เมธาวัฒน์ คูศิริวานิชกร

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('student.csv')

# %% [markdown]
# # สรุปปัญหาที่พบในข้อมูล

# %%
print("\n📊 สรุปปัญหาที่พบในข้อมูล:")
print(f"- ค่าหายทั้งหมด: {df.isnull().sum().sum()} ค่า")
print(f"- อายุผิดปกติ: {df[df['อายุ'] > 100]['อายุ'].values if any(df['อายุ'] > 100) else 'ไม่มี'}")
print(f"- GPA ผิดปกติ: {df[(df['GPA'] < 0) | (df['GPA'] > 4)]['GPA'].values if any((df['GPA'] < 0) | (df['GPA'] > 4)) else 'ไม่มี'}")
print(f"- รูปแบบการเขียนคณะ: {df['คณะ'].nunique()} แบบ")
print(f"- รูปแบบการเขียนเพศ: {df['เพศ'].nunique()} แบบ")
# Out:
# 📊 สรุปปัญหาที่พบในข้อมูล:
# - ค่าหายทั้งหมด: 15 ค่า
# - อายุผิดปกติ: [150.]
# - GPA ผิดปกติ: [-1.   4.5]
# - รูปแบบการเขียนคณะ: 14 แบบ
# - รูปแบบการเขียนเพศ: 8 แบบ

# %% [markdown]
# # ทำสำเนา จากข้อมูลต้นฉบับ

# %%
df_cleaned = df.copy()

# %%
df_cleaned
# Out:
#     รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 2          64003       NaN    NaN    Male         Science  3.67       175.0
# 3          64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5          64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6          64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9          64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    NaN     NaN             NaN  3.78         NaN
# ...

# %% [markdown]
# # เอา ช่อง ชื่อ ที่ไม่มีข้อมูลออก

# %%
df_cleaned = df_cleaned.dropna(subset=['ชื่อ'])

# %%
df_cleaned
# Out:
#     รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 3          64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5          64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6          64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9          64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    NaN     NaN             NaN  3.78         NaN
# 11         64012       นภา   22.0     ชาย           วิทย์   NaN       171.0
# ...

# %% [markdown]
# # เปลี่ยนข้อมูล ช่อง อายุ, ส่วนสูง, น้ำหนัก, ชั่วโมงเรียน_ต่อสัปดาห์ ที่เป็น NaN เป็นค่าเฉลี่ย & จัดการค่าผิดปกติ ในช่อง อายุ, GPA โดยเอาค่าเฉลี่ยจากการจัดการค่าผิดปกติมาใส่ก่อนเอาออก

# %%
Q1_age = df_cleaned['อายุ'].quantile(0.25)
Q3_age = df_cleaned['อายุ'].quantile(0.75)
IQR_age = Q3_age - Q1_age

Q1_gpa = df_cleaned['GPA'].quantile(0.25)
Q3_gpa = df_cleaned['GPA'].quantile(0.75)
IQR_gpa = Q3_gpa - Q1_gpa

lower_bound_age = Q1_age - 1.5 * IQR_age
upper_bound_age = Q3_age + 1.5 * IQR_age

lower_bound_gpa = Q1_gpa - 1.5 * IQR_gpa
upper_bound_gpa = Q3_gpa + 1.5 * IQR_gpa

# %%
df_cleaned_age_mean = df_cleaned[(df_cleaned['อายุ'] >= lower_bound_age) & (df_cleaned['อายุ'] <= upper_bound_age)]
df_cleaned_gpa_mean = df_cleaned[(df_cleaned['GPA'] >= lower_bound_gpa) & (df_cleaned['GPA'] <= upper_bound_gpa)]

# %%
mean_age = df_cleaned_age_mean['อายุ'].mean()
df_cleaned['อายุ']=df_cleaned['อายุ'].fillna(mean_age).astype(int)

mean_gpa = df_cleaned_gpa_mean['GPA'].mean()
df_cleaned['GPA']=df_cleaned['GPA'].fillna(mean_gpa).round(2)

mean_height = df_cleaned['ส่วนสูง_cm'].mean()
df_cleaned['ส่วนสูง_cm']=df_cleaned['ส่วนสูง_cm'].fillna(mean_height).round(1)

mean_weight = df_cleaned['น้ำหนัก_kg'].mean()
df_cleaned['น้ำหนัก_kg']=df_cleaned['น้ำหนัก_kg'].fillna(mean_weight).round(1)

mean_hour_per_week = df_cleaned['ชั่วโมงเรียน_ต่อสัปดาห์'].mean()
df_cleaned['ชั่วโมงเรียน_ต่อสัปดาห์']=df_cleaned['ชั่วโมงเรียน_ต่อสัปดาห์'].fillna(mean_hour_per_week).round(1)

# %%
df_cleaned = df_cleaned[(df_cleaned['อายุ'] >= lower_bound_age) & (df_cleaned['อายุ'] <= upper_bound_age)]
df_cleaned = df_cleaned[(df_cleaned['GPA'] >= lower_bound_gpa) & (df_cleaned['GPA'] <= upper_bound_gpa)]

# %%
df_cleaned
# Out:
#     รหัสนักศึกษา    ชื่อ  อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001   สมชาย    20     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002  สมหญิง    21    หญิง           วิทย์  3.45       165.0
# 4          64005    สมใจ    19       ญ           วิศวะ  3.89       160.0
# 7          64008    จิรา    20       F      ศิลปศาสตร์  2.98       180.0
# 8          64009  ชนาธิป    23       M            Arts  3.34       163.0
# 9          64010    ดารา    21    หญิง           ศิลป์  3.56       167.0
# 10         64011    ธีระ    20     NaN             NaN  3.78       167.3
# 11         64012     นภา    22     ชาย           วิทย์  3.42       171.0
# 12         64013   บุญมี    20    หญิง           วิศวฯ  3.23       169.0
# 13         64014   ปรีชา    21     ชาย    Liberal Arts  3.45       164.0
# 14         64015   พิมพ์    22  Female             Sci  3.67       162.0
# 15         64016    ภูมิ    19       ช     วิทยาศาสตร์  3.89       173.0
# ...

# %% [markdown]
# #ทำให้ช่องข้อมูล เพศ, คณะ ให้เป็นมาตรฐาน

# %%
def standardize_faculty(name):
    if name in ['วิทยาศาสตร์', 'วิทย์', 'Science', 'คณะวิทยาศาสตร์','Sci']:
        return 'วิทยาศาสตร์'
    elif name in ['ศิลปศาสตร์', 'ศิลป์', 'Arts','Liberal Arts']:
        return 'ศิลปศาสตร์'
    elif name in ['วิศวกรรมศาสตร์','วิศวะ','วิศวฯ','Engineering','วิศวกรรม']:
        return 'วิศวกรรมศาสตร์'
    else:
        return name

# %%
def standardize_sex(sex):
    if sex in ['ชาย', 'ช', 'M']:
        return 'ชาย'
    elif sex in ['หญิง', 'ญ', 'Female','F']:
        return 'หญิง'
    else:
        return sex

# %%
df_cleaned['คณะ'] = df_cleaned['คณะ'].apply(standardize_faculty)
df_cleaned['เพศ'] = df_cleaned['เพศ'].apply(standardize_sex)

# %%
df_cleaned
# Out:
#     รหัสนักศึกษา    ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001   สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002  สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 4          64005    สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 7          64008    จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009  ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010    ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011    ธีระ    20   NaN             NaN  3.78       167.3
# 11         64012     นภา    22   ชาย     วิทยาศาสตร์  3.42       171.0
# 12         64013   บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014   ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# 14         64015   พิมพ์    22  หญิง     วิทยาศาสตร์  3.67       162.0
# 15         64016    ภูมิ    19   ชาย     วิทยาศาสตร์  3.89       173.0
# ...

# %% [markdown]
# # เติมข้อมูลในช่อง เพศ, คณะ ที่เป็น NaN ด้วยค่าที่พบบ่อยที่สุด

# %%
df_cleaned['เพศ'].fillna(df_cleaned['เพศ'].mode()[0], inplace=True)
df_cleaned['คณะ'].fillna(df_cleaned['คณะ'].mode()[0], inplace=True)

# %%
df_cleaned
# Out:
#     รหัสนักศึกษา    ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001   สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002  สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 4          64005    สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 7          64008    จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009  ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010    ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011    ธีระ    20  หญิง     วิทยาศาสตร์  3.78       167.3
# 11         64012     นภา    22   ชาย     วิทยาศาสตร์  3.42       171.0
# 12         64013   บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014   ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# 14         64015   พิมพ์    22  หญิง     วิทยาศาสตร์  3.67       162.0
# 15         64016    ภูมิ    19   ชาย     วิทยาศาสตร์  3.89       173.0
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # One-Hot Encoding แปลงข้อมูลประเภทเป็นตัวเลข

# %%
df_encoded = pd.get_dummies(df_cleaned, columns=['คณะ'], dtype=int)
df_encoded
# Out:
#     รหัสนักศึกษา    ชื่อ  อายุ   เพศ   GPA  ส่วนสูง_cm  น้ำหนัก_kg  \
# 0          64001   สมชาย    20   ชาย  3.21       170.0        65.0
# 1          64002  สมหญิง    21  หญิง  3.45       165.0        58.0
# 4          64005    สมใจ    19  หญิง  3.89       160.0        52.0
# 7          64008    จิรา    20  หญิง  2.98       180.0        82.0
# 8          64009  ชนาธิป    23   ชาย  3.34       163.0        55.0
# 9          64010    ดารา    21  หญิง  3.56       167.0        60.0
# 10         64011    ธีระ    20  หญิง  3.78       167.3        68.0
# 11         64012     นภา    22   ชาย  3.42       171.0        63.6
# 12         64013   บุญมี    20  หญิง  3.23       169.0        72.0
# 13         64014   ปรีชา    21   ชาย  3.45       164.0        54.0
# 14         64015   พิมพ์    22  หญิง  3.67       162.0        56.0
# 15         64016    ภูมิ    19   ชาย  3.89       173.0        78.0
# 16         64017    มานี    20  หญิง  3.01       166.0        62.0
# ...

# %% [markdown]
# # การรวม Features สร้าง BMI

# %%
df_cleaned['BMI'] = (df_cleaned['น้ำหนัก_kg'] / (df_cleaned['ส่วนสูง_cm']/100)**2).round(2)
df_cleaned['สุขภาพ'] = pd.cut(df_cleaned['BMI'],
                                   bins=[0, 18.5, 25, 30, 100],
                                   labels=['ผอม', 'ปกติ', 'อ้วน', 'อ้วนมาก'])

# %%
df_cleaned
# Out:
#     รหัสนักศึกษา    ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001   สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002  สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 4          64005    สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 7          64008    จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009  ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010    ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011    ธีระ    20  หญิง     วิทยาศาสตร์  3.78       167.3
# 11         64012     นภา    22   ชาย     วิทยาศาสตร์  3.42       171.0
# 12         64013   บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014   ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# 14         64015   พิมพ์    22  หญิง     วิทยาศาสตร์  3.67       162.0
# 15         64016    ภูมิ    19   ชาย     วิทยาศาสตร์  3.89       173.0
# ...
